# %%
from IPython.display import Image
Image("E:/code/0.Info/ds1.png")

# %% [markdown]
# ### what is the work of Data Analyst

# %%
from IPython.display import Image
Image("E:/code/0.Info/ds2.png")

# %% [markdown]
# ### Languages need to know
# - python
# - R language

# %% [markdown]
# ### DataBases to learn(atleast one sql and one nosql)
# - Mysql
# - MongoDB
# - Cassandra
# - ElasticSearch

# %% [markdown]
# ### Business Intelligence Tools
# - power BI
# - tableau
# - qlikview
# - cognos
# - jaspersoft

# %% [markdown]
# ### Technical skills Required
# - basic mathematics and statistics
# - programing skills
# - domain knowledge
# - data understanding
# - ETL tool knowledge
# - identifying the structured data and  unstructured data
# - good in exploratory data analysis
