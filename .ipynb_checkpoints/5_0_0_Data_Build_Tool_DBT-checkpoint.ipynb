# %% [markdown]
# Notes : https://publish.obsidian.md/datavidhya/DataVidhya+Course+Notes+%26+Resources

# %% [markdown]
# Review DBT warnings realted to the deprecated functionality  : https://docs.getdbt.com/reference/deprecations

# %%
from IPython.display import Image
Image('.\img\dbt.png')

# %% [markdown]
# #### Prerequisite
# - Basics of sql
# - Snowflake Data Warehouse
# - Data Engineering Foundations
#
# #### what is DBT?
# - At its core DBT is a transformation tool that allows you to write the modular SQL Queries to transform raw data  into analytics ready data models.
# - DBT doesn't extract or load data it focuses exclusively on the transformation step in the ELT(Extract, Load, Transform) process

# %% [markdown]
# 🧰 What is DBT (Data Build Tool)?
# DBT is an open-source tool that helps data analysts and engineers transform raw data in their data warehouse using SQL. It focuses on the T (Transform) part of the ETL or ELT process.
#
# 🏗️ Core Idea
# Instead of transforming data before loading (ETL), DBT assumes the data is already loaded into a warehouse (like BigQuery, Snowflake, Redshift, etc.) and applies SQL transformations inside the warehouse (ELT).
#
#
# | Feature                | Description                                        |
# | ---------------------- | -------------------------------------------------- |
# | **SQL-based modeling** | Write models (transforms) as `.sql` files          |
# | **Modularity**         | Build data pipelines with reusable models          |
# | **Version Control**    | Integrate easily with Git                          |
# | **Documentation**      | Auto-generates docs from model descriptions        |
# | **Testing**            | Built-in data testing (e.g., uniqueness, not null) |
# | **Lineage Graph**      | Visual graph of model dependencies                 |
# | **CI/CD friendly**     | Integrates with CI tools to auto-deploy pipelines  |
#
# #### How It Works (ELT)
# Extract → Pull raw data into warehouse (done by another tool).
#
# Load → Raw data sits in raw tables.
#
# Transform (via DBT):
#
# You write SQL SELECT statements in .sql files.
#
# DBT runs them in order and creates views or tables in your warehouse.
#
# Each model can depend on others (via ref()).

# %%
from IPython.display import Image
Image('.\img\dbt2.png')

# %%
from IPython.display import Image
Image('.\img\dbt3.png')

# %%
from IPython.display import Image
Image('.\img\dbt4.png')

# %%
from IPython.display import Image
Image('.\img\dbt5.png')

# %%
from IPython.display import Image
Image('.\img\dbt6.png')

# %% [markdown]
# #### Why DBT?
# Before DBT, data transformation work was often done through :
# - sql scripts: Manually maintained, often with no version control
# - ETL tools: complex and expensive tools that required specialized knowledge
# - Custom code: Python, scala or other Programming languages used to transform data

# %% [markdown]
# 1. Modularity: Break down complex transformations into manageable pieces
# 2. Reusability: Create and reuse common SQL patterns across your project
# 3. Testing framework: Built-in testing capabilities to ensure data quality
# 4. Documentation generation: Automatically generate documentation for your data models
# 5. Dependency management: Automatically handle the order of model execution
# 6. Development workflow: Support for development environments separate from production
#
# <b>Data Warehouse : </b>
# A data warehouse is a central repository designed for storing and analyzing large volumes of structured data from various sources.
#
# <b>Data Lake : </b>
# A data lake is a storage repository that holds a vast amount of raw data in its native format until it's needed.
#
# <b>Data Lakehouse : </b>
# A data lakehouse is a relatively new architecture that combines the best elements of data warehouses and data lakes.

# %%
from IPython.display import Image
Image('.\img\dbt7.png')

# %%
from IPython.display import Image
Image('.\img\dbt8.png')

# %%
from IPython.display import Image
Image('.\img\dbt9.png')

# %%
from IPython.display import Image
Image('.\img\dbt10.png')

# %% [markdown]
#  #### Basic DBT Project Structure
#
# dbt_project/
# │
# ├── models/
# │   ├── staging/
# │   ├── marts/
# │
# ├── dbt_project.yml  # Config
# └── profiles.yml      # Connection to warehouse

# %% [markdown]
# https://grouplens.org/datasets/movielens/20m/

# %% [markdown]
# how to upload the data in snowflake:
# 1. using snowflake database UI to upload the data
# 2. upload your data to S3. use snowflake to connect to S3 and then load your data to the snowflake
# 3.

# %%
# !pip install dbt-snowflake

# %% [markdown]
# #### add extensions
# - dbt formatter
# - power user for dbt
# - vscode-icons

# %% [markdown]
# https://docs.getdbt.com/docs/build/materializations

# %%
from IPython.display import Image
Image('.\img\diagram.png')
